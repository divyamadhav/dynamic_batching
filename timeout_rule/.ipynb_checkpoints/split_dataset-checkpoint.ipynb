# %%
import pandas as pd
import numpy as np
from numpy import argmax
from numpy import sqrt
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.utils import resample
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from statistics import median
import pickle
import csv
import multiprocess
import warnings
warnings.filterwarnings("ignore")

# %%
project_list = [
    'graylog2-server.csv',
    'android.csv',
    'gradle.csv',
    'okhttp.csv',
    'cloudify.csv',
]

# %%
def get_first_failures(df):
    
    results = df['tr_status'].tolist()
    length = len(results)
    verdict = ['keep']
    prev = results[0]
    
    for i in range(1, length):
        if results[i] == 0:
            if prev == 0:
                verdict.append('discard')
                #print(i+1)
            else:
                verdict.append('keep')
        else:
            verdict.append('keep')
        prev = results[i]
    
    df['verdict'] = verdict
    df = df[ df['verdict'] == 'keep' ]
    df.drop('verdict', inplace=True, axis=1)
    return df

# %%
folder_path = '../data/extracted_project_travis/'
write_path = 'datasets/'

# %%
for p in project_list:
    
    p_name = p.split('.')[0]
    data = pd.read_csv(folder_path + p)
    data = get_first_failures(data)
    sec = len(data)//10
    
    for i in range(9):
        sec_data = data.iloc[i*sec:i*sec+sec]
        b_ids = sec_data['tr_build_id'].tolist()
        file_name = write_path + p_name + '_' + str(i) + '.pkl'
        with open(file_name, 'wb') as wfile:
            pickle.dump(b_ids, wfile)
        
    
    i = i+1
    sec_data = data.iloc[i*sec:]
    b_ids = sec_data['tr_build_id'].tolist()
    file_name = write_path + p_name + '_' + str(i) + '.pkl'
    with open(file_name, 'wb') as wfile:
        pickle.dump(b_ids, wfile)

# %%
data
# Out:
#       tr_build_id          gh_project_name  gh_is_pr gh_pr_created_at  \
# 0         1494869  CloudifySource/cloudify     False              NaN
# 1         1494892  CloudifySource/cloudify     False              NaN
# 2         1495071  CloudifySource/cloudify     False              NaN
# 3         1495163  CloudifySource/cloudify     False              NaN
# 4         1495971  CloudifySource/cloudify     False              NaN
# ...           ...                      ...       ...              ...
# 5737     38476781  CloudifySource/cloudify     False              NaN
# 5738     39786032  CloudifySource/cloudify     False              NaN
# 5739     42300951  CloudifySource/cloudify     False              NaN
# 5740     42301261  CloudifySource/cloudify     False              NaN
# 5741     42456963  CloudifySource/cloudify     False              NaN
#
#       gh_pull_req_num gh_lang git_merged_with                      git_branch  \
# 0                 NaN    java             NaN                          master
# 1                 NaN    java             NaN                          master
# 2                 NaN    java             NaN                          master
# 3                 NaN    java             NaN                          master
# 4                 NaN    java             NaN                          master
# ...               ...     ...             ...                             ...
# 5737              NaN    java             NaN          2_7_1_ga_softlayer_poc
# 5738              NaN    java             NaN          2_7_1_ga_softlayer_poc
# 5739              NaN    java             NaN                       2_7_0_rc2
# 5740              NaN    java             NaN                       2_7_0_rc2
# 5741              NaN    java             NaN  2.7.0_rc2_build6000_11_27_2014
#
#       gh_num_commits_in_push  \
# 0                        1.0
# 1                        2.0
# 2                        1.0
# 3                        2.0
# 4                        1.0
# ...                      ...
# 5737                     1.0
# 5738                     1.0
# 5739                     1.0
# 5740                     1.0
# 5741                     1.0
#
#                                      gh_commits_in_push  ...  \
# 0              4d48ae7f41c6fc015be3e81d0d2e34e6ed301462  ...
# 1     9ef2e28be96a10fbf4c7ec51b55d327252da96a2#15e26...  ...
# 2              42e7dd035c2868b2fb1fad9fd19e7047323e492f  ...
# 3     4b71fe25f2085d563b8b83a84a32ea887f7672a5#c8170...  ...
# 4              cc8f4470498e11a0775a7466b649f34270ed8d38  ...
# ...                                                 ...  ...
# 5737           846298fa42310dcfbb8eb60fdfbc5f72af47284c  ...
# 5738           48bbb7f4872110c937ebb527980ca339991e928d  ...
# 5739           76d0844f9220c6aa3349c939b0fc62883fca692d  ...
# 5740           5021ce3875528b94cece1dad5e8f4a00b05cfec3  ...
# 5741           5021ce3875528b94cece1dad5e8f4a00b05cfec3  ...
#
#      tr_log_bool_tests_ran tr_log_bool_tests_failed  tr_log_num_tests_ok  \
# 0                    False                      NaN                  NaN
# 1                    False                      NaN                  NaN
# 2                    False                      NaN                  NaN
# 3                    False                      NaN                  NaN
# 4                    False                      NaN                  NaN
# ...                    ...                      ...                  ...
# 5737                  True                    False                  2.0
# 5738                  True                    False                  2.0
# 5739                  True                    False                  2.0
# 5740                  True                    False                  2.0
# 5741                  True                    False                  2.0
#
#      tr_log_num_tests_failed  tr_log_num_tests_run tr_log_num_tests_skipped  \
# 0                        NaN                   NaN                      NaN
# 1                        NaN                   NaN                      NaN
# 2                        NaN                   NaN                      NaN
# 3                        NaN                   NaN                      NaN
# 4                        NaN                   NaN                      NaN
# ...                      ...                   ...                      ...
# 5737                     0.0                   2.0                      0.0
# 5738                     0.0                   2.0                      0.0
# 5739                     0.0                   2.0                      0.0
# 5740                     0.0                   2.0                      0.0
# 5741                     0.0                   2.0                      0.0
#
#       tr_log_tests_failed tr_log_testduration tr_log_buildduration  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 5737                  NaN              110.17                146.0
# 5738                  NaN              102.90                134.0
# 5739                  NaN              177.29                207.0
# 5740                  NaN              175.51                205.0
# 5741                  NaN              163.88                190.0
#
#      build_successful
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 5737             True
# 5738             True
# 5739            False
# 5740             True
# 5741            False
#
# [5742 rows x 62 columns]
