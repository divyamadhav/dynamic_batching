# %%
import pandas as pd

# %%
baseline_dynamic = pd.read_csv('baseline_dynamic_batching_timed.csv')
ci_skip_baseline_dynamic = pd.read_csv('ci_skipped_baseline_dynamic_batching_timed.csv')
baseline_static = pd.read_csv('static_batching_duration.csv')
ci_skip_baseline_static = pd.read_csv('ci_skipped_static_batching_duration.csv')

project_list = list(set(baseline_static['project'].tolist()))

# %%
print(len(baseline_dynamic))
baseline_dynamic = baseline_dynamic[(baseline_dynamic['project'].isin(project_list))]
print(len(baseline_dynamic))

baseline_dynamic = baseline_dynamic.rename(columns={'duration': 'total_duration'})
baseline_dynamic.columns
# Out:
# 129
# 129
# Index(['project', 'algorithm', 'ci_skip', 'batch_size', 'total_duration',
#        'testall_duration', 'time_saved', 'builds_saved', 'median_delay',
#        'testall_size'],
#       dtype='object')

# %%
our_dynamic = pd.read_csv('lwd_time_saved.csv')
our_ci_dynamic = pd.read_csv('ci_skipped_lwd_time_saved.csv')
mfu = pd.read_csv('mfu_time_saved.csv')

# %%
project_list = list(set(our_dynamic['project'].tolist()))

# %%
our_dynamic['ci_skip'] = [0]*len(our_dynamic)
our_ci_dynamic['ci_skip'] = [1]*len(our_ci_dynamic)
baseline_static['ci_skip'] = [0]*len(baseline_static)
ci_skip_baseline_dynamic['ci_skip'] = [1]*len(ci_skip_baseline_dynamic)
ci_skip_baseline_static['ci_skip'] = [1]*len(ci_skip_baseline_static)

# %%
baseline_dynamic['method'] = ['baseline_dynamic']*len(baseline_dynamic)
our_dynamic['method'] = ['new_dynamic']*len(our_dynamic)
our_ci_dynamic['method'] = ['new_dynamic']*len(our_ci_dynamic)
baseline_static['method'] = ['baseline_static']*len(baseline_static)
ci_skip_baseline_dynamic['method'] = ['baseline_dynamic']*len(ci_skip_baseline_dynamic)
ci_skip_baseline_static['method'] = ['baseline_static']*len(ci_skip_baseline_static)

# %%
final_results = pd.DataFrame()
final_results = final_results.append(baseline_dynamic)
final_results = final_results.append(ci_skip_baseline_dynamic)
final_results = final_results.append(our_dynamic)
final_results = final_results.append(our_ci_dynamic)
final_results = final_results.append(mfu)
final_results = final_results.append(baseline_static)
final_results = final_results.append(ci_skip_baseline_static)

# %%
final_results
# Out:
#                            project     algorithm  ci_skip batch_size  \
# 0    SpongePowered-SpongeForge.csv   BATCHBISECT      0.0         -1
# 1                DSpace-DSpace.csv   BATCHBISECT      0.0         -1
# 2              xetorthio-jedis.csv   BATCHBISECT      0.0         -1
# 3              samtools-htsjdk.csv   BATCHBISECT      0.0         -1
# 4              caelum-vraptor4.csv   BATCHBISECT      0.0         -1
# ..                             ...           ...      ...        ...
# 425             dreamhead-moco.csv    BATCHSTOP4      1.0          8
# 426             dreamhead-moco.csv    BATCHSTOP4      1.0         16
# 427             dreamhead-moco.csv  BATCHDIVIDE4      1.0          4
# 428             dreamhead-moco.csv  BATCHDIVIDE4      1.0          8
# 429             dreamhead-moco.csv  BATCHDIVIDE4      1.0         16
#
#      total_duration  testall_duration  time_saved  builds_saved  median_delay  \
# 0         1578943.0         3313879.0   52.353631     40.376636          -1.0
# 1          351918.0         1063649.0   66.914085     61.675127          -1.0
# 2          274417.0          566818.0   51.586400     47.738693          -1.0
# 3          506429.0         1704858.0   70.294945     63.779988          -1.0
# 4          121081.0          228882.0   47.098942     43.137255          -1.0
# ..              ...               ...         ...           ...           ...
# 425       4023913.0         4738630.0   15.082777     32.043625           NaN
# 426       4370343.0         4738630.0    7.772014     30.563490           NaN
# 427       3428839.0         4738630.0   27.640711     32.225396           NaN
# 428       4023913.0         4738630.0   15.082777     32.043625           NaN
# 429       4617987.0         4738630.0    2.545947     32.199429           NaN
#
#     testall_size            method  duration  Unnamed: 0 update_method  \
# 0           3133  baseline_dynamic       NaN         NaN           NaN
# 1           1576  baseline_dynamic       NaN         NaN           NaN
# 2           1592  baseline_dynamic       NaN         NaN           NaN
# 3           1709  baseline_dynamic       NaN         NaN           NaN
# 4           1428  baseline_dynamic       NaN         NaN           NaN
# ..           ...               ...       ...         ...           ...
# 425         3851   baseline_static       NaN       425.0           NaN
# 426         3851   baseline_static       NaN       426.0           NaN
# 427         3851   baseline_static       NaN       427.0           NaN
# 428         3851   baseline_static       NaN       428.0           NaN
# 429         3851   baseline_static       NaN       429.0           NaN
#
#      factor  builds_made  num_of_builds  total_builds
# 0       NaN          NaN            NaN           NaN
# 1       NaN          NaN            NaN           NaN
# 2       NaN          NaN            NaN           NaN
# 3       NaN          NaN            NaN           NaN
# 4       NaN          NaN            NaN           NaN
# ..      ...          ...            ...           ...
# 425     NaN          NaN            NaN        2617.0
# 426     NaN          NaN            NaN        2674.0
# 427     NaN          NaN            NaN        2610.0
# 428     NaN          NaN            NaN        2617.0
# 429     NaN          NaN            NaN        2611.0
#
# [3053 rows x 18 columns]

# %%
final_results = final_results.loc[:, ~final_results.columns.str.contains('^Unnamed')]

# %%
final_results.to_csv('ci_skip_all_results.csv')

# %%
baseline_static.columns
# Out:
# Index(['Unnamed: 0', 'project', 'algorithm', 'batch_size', 'total_duration',
#        'testall_duration', 'time_saved', 'builds_saved', 'total_builds',
#        'testall_size', 'ci_skip', 'method'],
#       dtype='object')

# %%
baseline_dynamic.columns
# Out:
# Index(['project', 'algorithm', 'ci_skip', 'batch_size', 'total_duration',
#        'testall_duration', 'time_saved', 'builds_saved', 'median_delay',
#        'testall_size', 'method'],
#       dtype='object')

# %%
our_dynamic.columns
# Out:
# Index(['Unnamed: 0', 'project', 'algorithm', 'batch_size', 'update_method',
#        'factor', 'total_duration', 'testall_duration', 'time_saved',
#        'builds_made', 'builds_saved', 'testall_size', 'ci_skip', 'method'],
#       dtype='object')

# %%
baseline_dynamic[baseline_dynamic['algorithm'] == 'BATCHDIVIDE4']
# Out:
#                              project     algorithm  ci_skip  batch_size  \
# 86     SpongePowered-SpongeForge.csv  BATCHDIVIDE4        0          -1
# 87                 DSpace-DSpace.csv  BATCHDIVIDE4        0          -1
# 88               xetorthio-jedis.csv  BATCHDIVIDE4        0          -1
# 89               samtools-htsjdk.csv  BATCHDIVIDE4        0          -1
# 90               caelum-vraptor4.csv  BATCHDIVIDE4        0          -1
# 91              cloudfoundry-uaa.csv  BATCHDIVIDE4        0          -1
# 92             keycloak-keycloak.csv  BATCHDIVIDE4        0          -1
# 93   open-keychain-open-keychain.csv  BATCHDIVIDE4        0          -1
# 94               ratpack-ratpack.csv  BATCHDIVIDE4        0          -1
# 95                   apache-tajo.csv  BATCHDIVIDE4        0          -1
# 96      Graylog2-graylog2-server.csv  BATCHDIVIDE4        0          -1
# 97   typetools-checker-framework.csv  BATCHDIVIDE4        0          -1
# 98         dropwizard-dropwizard.csv  BATCHDIVIDE4        0          -1
# 99             ngageoint-geowave.csv  BATCHDIVIDE4        0          -1
# 100   FasterXML-jackson-databind.csv  BATCHDIVIDE4        0          -1
# 101       sparklemotion-nokogiri.csv  BATCHDIVIDE4        0          -1
# 102       CloudSlang-cloud-slang.csv  BATCHDIVIDE4        0          -1
# 103    floragunncom-search-guard.csv  BATCHDIVIDE4        0          -1
# 104            mybatis-mybatis-3.csv  BATCHDIVIDE4        0          -1
# 105              structr-structr.csv  BATCHDIVIDE4        0          -1
# 106          orbeon-orbeon-forms.csv  BATCHDIVIDE4        0          -1
# 107             puniverse-quasar.csv  BATCHDIVIDE4        0          -1
# 108                  p6spy-p6spy.csv  BATCHDIVIDE4        0          -1
# 109           grails-grails-core.csv  BATCHDIVIDE4        0          -1
# 110   SpongePowered-SpongeCommon.csv  BATCHDIVIDE4        0          -1
# 111            killbill-killbill.csv  BATCHDIVIDE4        0          -1
# 112            junit-team-junit5.csv  BATCHDIVIDE4        0          -1
# 113                  square-wire.csv  BATCHDIVIDE4        0          -1
# 114                  nutzam-nutz.csv  BATCHDIVIDE4        0          -1
# 115         rackerlabs-blueflood.csv  BATCHDIVIDE4        0          -1
# 116               yegor256-takes.csv  BATCHDIVIDE4        0          -1
# 117            geotools-geotools.csv  BATCHDIVIDE4        0          -1
# 118      CloudifySource-cloudify.csv  BATCHDIVIDE4        0          -1
# 119               dreamhead-moco.csv  BATCHDIVIDE4        0          -1
# 120               naver-pinpoint.csv  BATCHDIVIDE4        0          -1
# 121       SonarSource-sonar-java.csv  BATCHDIVIDE4        0          -1
# 122        apache-jackrabbit-oak.csv  BATCHDIVIDE4        0          -1
# 123                JabRef-jabref.csv  BATCHDIVIDE4        0          -1
# 124             linkedin-gobblin.csv  BATCHDIVIDE4        0          -1
# 125           sakaiproject-sakai.csv  BATCHDIVIDE4        0          -1
# 126        checkstyle-checkstyle.csv  BATCHDIVIDE4        0          -1
# 127                    jOOQ-jOOQ.csv  BATCHDIVIDE4        0          -1
# 128                  apache-nifi.csv  BATCHDIVIDE4        0          -1
#
#      total_duration  testall_duration  time_saved  builds_saved  median_delay  \
# 86        1598902.0         3313879.0   51.751346     47.973189            -1
# 87         433416.0         1063649.0   59.251971     64.911168            -1
# 88         256154.0          566818.0   54.808422     54.522613            -1
# 89         527677.0         1704858.0   69.048625     67.641896            -1
# 90         128633.0          228882.0   43.799425     47.478992            -1
# 91         664648.0         1916617.0   65.321814     67.832168            -1
# 92        2534453.0         4564913.0   44.479709     52.602151            -1
# 93         429671.0          698932.0   38.524635     36.623668            -1
# 94        1602822.0         2004584.0   20.042163     11.567164            -1
# 95              NaN               NaN         NaN     34.110334            -1
# 96        1035245.0         3250767.0   68.153823     65.852885            -1
# 97       17222946.0        36090133.0   52.277965     40.148699            -1
# 98        1241137.0         3857892.0   67.828622     68.019802            -1
# 99        8277538.0        25407015.0   67.420266     56.918882            -1
# 100        304929.0          653412.0   53.332813     44.578313            -1
# 101       3464468.0         7840328.0   55.812206     48.790115            -1
# 102       1102140.0         2125647.0   48.150375     46.334716            -1
# 103       3727912.0        10515790.0   64.549387     66.128149            -1
# 104        817482.0         3118789.0   73.788480     71.687587            -1
# 105       7699322.0        10157371.0   24.199658     21.138535            -1
# 106       2127019.0         2722955.0   21.885635     18.839488            -1
# 107        448339.0          973636.0   53.952093     49.408051            -1
# 108       1413732.0         2320366.0   39.072888     26.086957            -1
# 109       1276051.0         1863380.0   31.519550     14.689266            -1
# 110       1428845.0         3085728.0   53.695044     50.336474            -1
# 111             NaN               NaN         NaN     32.973902            -1
# 112         96020.0          327087.0   70.643896     66.804245            -1
# 113         96623.0          279385.0   65.415824     70.142602            -1
# 114       2482864.0         3600676.0   31.044504     25.849594            -1
# 115       2921667.0         5554911.0   47.403892     45.063406            -1
# 116       1057620.0         1809229.0   41.543055     44.025631            -1
# 117             NaN               NaN         NaN     30.792541            -1
# 118             NaN               NaN         NaN     40.170940            -1
# 119       3724414.0         5320059.0   29.992994     41.359003            -1
# 120        562474.0         1560533.0   63.956289     62.418301            -1
# 121             NaN               NaN         NaN     52.405849            -1
# 122             NaN               NaN         NaN     14.253692            -1
# 123        388774.0         1065044.0   63.496907     60.761705            -1
# 124       9417362.0        11841513.0   20.471632     20.799770            -1
# 125       2543502.0         5685469.0   55.263110     57.466421            -1
# 126             NaN               NaN         NaN     78.499454            -1
# 127       1729740.0         4135475.0   58.173124     49.058244            -1
# 128       2371120.0         4088637.0   42.007080     26.986625            -1
#
#      testall_size            method
# 86           3133  baseline_dynamic
# 87           1576  baseline_dynamic
# 88           1592  baseline_dynamic
# 89           1709  baseline_dynamic
# 90           1428  baseline_dynamic
# 91            286  baseline_dynamic
# 92           2325  baseline_dynamic
# 93           1783  baseline_dynamic
# 94           1876  baseline_dynamic
# 95           1287  baseline_dynamic
# 96           3154  baseline_dynamic
# 97           4573  baseline_dynamic
# 98           2020  baseline_dynamic
# 99           2934  baseline_dynamic
# 100          2241  baseline_dynamic
# 101          5827  baseline_dynamic
# 102          2169  baseline_dynamic
# 103          3652  baseline_dynamic
# 104          2151  baseline_dynamic
# 105          2512  baseline_dynamic
# 106          2654  baseline_dynamic
# 107          1267  baseline_dynamic
# 108          1288  baseline_dynamic
# 109          1062  baseline_dynamic
# 110          3715  baseline_dynamic
# 111          6399  baseline_dynamic
# 112          1696  baseline_dynamic
# 113          1122  baseline_dynamic
# 114          4561  baseline_dynamic
# 115          2208  baseline_dynamic
# 116          2653  baseline_dynamic
# 117          4290  baseline_dynamic
# 118          5148  baseline_dynamic
# 119          4415  baseline_dynamic
# 120          2142  baseline_dynamic
# 121         12241  baseline_dynamic
# 122          7584  baseline_dynamic
# 123          2862  baseline_dynamic
# 124          3476  baseline_dynamic
# 125          3797  baseline_dynamic
# 126         46743  baseline_dynamic
# 127          3451  baseline_dynamic
# 128          1271  baseline_dynamic
