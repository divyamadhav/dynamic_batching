# %%
import pandas as pd

# %%
df = pd.read_csv('ci_skip_all_results.csv')

# %%
df['final_methods'] = df['algorithm'] + ' ' + df['update_method'] + ' ' + df['factor'].astype(str)

# %%
bd = df[ df['method'] == 'baseline_dynamic']
bs = df[ df['method'] == 'baseline_static']
ld = df[ df['method'] == 'new_dynamic']

# %%
algorithms = ['BATCHBISECT', 'BATCHSTOP4', 'BATCHDIVIDE4']

# %%
dyn_df = pd.DataFrame()
sta_df = pd.DataFrame()

# %%
final_methods_lwd = list(set(ld['final_methods'].tolist()))

# %%
bd = bd.sort_values(by='project')
project_list = list(set(bd['project'].tolist()))

# %%
dyn_df['project'] = project_list
sta_df['project'] = project_list

# %%
for alg in algorithms:
    
    bd_alg = bd[ (bd['algorithm'] == alg) & (bd['ci_skip'] == 0)]
    bs_alg = bs[ (bs['algorithm'] == alg) & (bs['ci_skip'] == 0)]
    ld_alg = ld[ (ld['algorithm'] == alg) & (ld['ci_skip'] == 0)]
    
    bd_alg = bd_alg.sort_values(by='project')
    
    dyn_col_name = 'Dynamic Baseline ' + alg
    dyn_df[dyn_col_name] = bd_alg['builds_saved']
    
    batch_sizes = list(set(bs_alg['batch_size'].tolist()))
    
    for b in batch_sizes:
        bs_alg_b = bs_alg[ bs_alg['batch_size'] == b]
        
        bs_alg_b = bs_alg_b.sort_values(by='project')
        
        static_col_name = 'Static Baseline ' + alg + ' ' + str(b)
        sta_df[static_col_name] = bs_alg_b['builds_saved']

# %%
for alg in algorithms:
    
    ld_alg = ld[ (ld['algorithm'] == alg) & (ld['ci_skip'] == 0)]
    
    for f in final_methods_lwd:
        
        ld_alg_f = ld_alg[ ld_alg['final_methods'] == f]
        
        dyn_df[f] = ld_alg_f['builds_saved']
        sta_df[f] = ld_alg_f['builds_saved']

# %%
dynamic_time_saved.ipynb
# Out:
#       Unnamed: 0                        project     algorithm  ci_skip  \
# 0              0  SpongePowered-SpongeForge.csv   BATCHBISECT        0
# 1              1              DSpace-DSpace.csv   BATCHBISECT        0
# 2              2      essentials-Essentials.csv   BATCHBISECT        0
# 3              3            xetorthio-jedis.csv   BATCHBISECT        0
# 4              4            samtools-htsjdk.csv   BATCHBISECT        0
# ...          ...                            ...           ...      ...
# 5210         495      checkstyle-checkstyle.csv    BATCHSTOP4        1
# 5211         496      checkstyle-checkstyle.csv    BATCHSTOP4        1
# 5212         497      checkstyle-checkstyle.csv  BATCHDIVIDE4        1
# 5213         498      checkstyle-checkstyle.csv  BATCHDIVIDE4        1
# 5214         499      checkstyle-checkstyle.csv  BATCHDIVIDE4        1
#
#       batch_size   duration  testall_duration  time_saved  builds_saved  \
# 0             -1  1342808.0         3313879.0   40.520731     40.376636
# 1             -1   253053.0         1063649.0   23.791025     61.675127
# 2             -1    65813.0           68435.0   96.168627     -6.741573
# 3             -1   222763.0          566818.0   39.300622     47.738693
# 4             -1   411775.0         1704858.0   24.153038     63.779988
# ...          ...        ...               ...         ...           ...
# 5210           8        NaN       234335568.0   22.826991     74.946614
# 5211          16        NaN       234335568.0   17.947261     79.563897
# 5212           4        NaN       234335568.0   33.041122     65.223271
# 5213           8        NaN       234335568.0   22.826991     74.946614
# 5214          16        NaN       234335568.0   10.054164     62.779386
#
#       median_delay  testall_size            method update_method  factor  \
# 0             -1.0          3133  baseline_dynamic           NaN     NaN
# 1             -1.0          1576  baseline_dynamic           NaN     NaN
# 2             -1.0            89  baseline_dynamic           NaN     NaN
# 3             -1.0          1592  baseline_dynamic           NaN     NaN
# 4             -1.0          1709  baseline_dynamic           NaN     NaN
# ...            ...           ...               ...           ...     ...
# 5210           4.0         42146   baseline_static           NaN     NaN
# 5211           8.0         42146   baseline_static           NaN     NaN
# 5212           2.0         42146   baseline_static           NaN     NaN
# 5213           4.0         42146   baseline_static           NaN     NaN
# 5214           8.0         42146   baseline_static           NaN     NaN
#
#       total_duration  builds_made  num_of_builds final_methods
# 0                NaN          NaN            NaN           NaN
# 1                NaN          NaN            NaN           NaN
# 2                NaN          NaN            NaN           NaN
# 3                NaN          NaN            NaN           NaN
# 4                NaN          NaN            NaN           NaN
# ...              ...          ...            ...           ...
# 5210      53491758.0          NaN            NaN           NaN
# 5211      42056817.0          NaN            NaN           NaN
# 5212      77427102.0          NaN            NaN           NaN
# 5213      53491758.0          NaN            NaN           NaN
# 5214      23560482.0          NaN            NaN           NaN
#
# [5215 rows x 18 columns]
