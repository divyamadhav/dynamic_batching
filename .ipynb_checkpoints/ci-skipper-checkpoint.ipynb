# %%
import pandas as pd
import requests
import json
import time
from git import Repo
import re
from pathlib import Path
import git
from projects import project_list

# %%
fe = open('file_extensions.json', 'r')
file_extensions = json.load(fe)
types = list(file_extensions.keys())

# %%
def ignoreTheFormate(string_code):
    int1 = re.sub('/\/\/(.*)|\/\*(\*(?!\/)|[^*])*\*\//g', '', string_code) #removing single and multiline java comments
    int2 = re.sub('/([\\\]+<>=*(){}[,;-])/g', "\n$1\n", int1) 
    int3 = re.sub('/\s(\s*)/g', "\n", int2) #removing white spaces
    return int3.strip()

# %%
def getType(extension):
    
    for i in range(len(types)):
        if extension in file_extensions[types[i]]:
            return types[i]

    if (extension == ''):
        file_name = path.basename(file)
        if (file_name.indexOf('.git') == 0 |
            file_name.indexOf('.bzr') == 0 |
            file_name.indexOf('.svn') == 0 |
            file_name.indexOf('.cvs') == 0):
            return 'meta'
    
    return "unknown"

# %%
discard_list = []
for p in project_list[:3]:
    tr_data = pd.read_csv('data/25_1_travis_data/' + p)
    
    branch_type = tr_data['git_branch'].tolist()
    if 'master' in branch_type:
        data = tr_data[ tr_data['git_branch'] == 'master']
    else:
        data = tr_data[ tr_data['git_branch'] == 'trunk']
        
    if len(data) == 0:
        print('Could not continue for {}'.format(p))
        discard_list.append(p)
        continue
    
    repo_name = p.split('/')[0]
    clone_dir = 'project_clones/' + repo_name
    
    repo = Repo(clone_dir)
    verdict_list = [] #final decision

    for x in range(len(tr_data)):
        row = tr_data.iloc[x]
        commit_id = row['git_trigger_commit']
        print(commit_id)
        
        try:
            commit = repo.commit(commit_id)
        except:
            print('omitting {}'.format(commit_id))
            verdict_list.append(0)
            continue

        file_flag_list = []
        code_flag_list = []
        format_flag_list = []

        verdict = 1
    
        for file_name in commit.stats.files:

            extension = '.' + file_name.split('.')[-1]
            t = getType(extension)

            if (t == 'meta') | (t == 'media') | (t == 'doc'):
                file_flag_list.append(1)
                verdict = verdict & 1
                #we have found non-source code changes
                #we have found meta file changes

                #we have found that this file can be skipped 

            elif extension == '.java':
                try:
                    new_version = ignoreTheFormate(repo.git.show('{}:{}'.format(commit_id, file_name)))
                    old_version = ignoreTheFormate(repo.git.show('{}:{}'.format(commit_id + '~', file_name)))

                    if old_version != new_version:
                        #we have found code changes
                        #we have found that this file cannot be skipped
                        code_flag_list.append(0)
                        verdict = verdict & 0
                    else:
                        #we have found file formatting or comment changes
                        #we have found that this file can be skipped 
                        format_flag_list.append(1)
                        verdict = verdict & 1
                except:
                    #file added or deleted
                    print('File {} added or deleted'.format(file_name))
                    verdict = verdict & 0

            else:
                #out of skip rules scope
                verdict = verdict & 0
                continue

        verdict_list.append(verdict)
    
    tr_data['verdict'] = verdict_list
    p_name = p.split('/')[1]
    tr_data.to_csv( 'ci_skip_data/extracted_project_travis/'+ p_name )
    
    print(verdict_list.count(1), len(verdict_list), 100*verdict_list.count(1)/len(verdict_list))
# Out:
# 70329a4aaa53659e943e96cd5f2238f016489fbd
# 0730aa491f4ac1fbd29f3866c5601d5415384e2a
# ebde06a0cd90d0125835108ade3c713c7cabf203
# 27d095a00c45fa864d1f471a1265f082fcdea4b6
# File common/buildcraft/core/gui/slots/SlotArchitect.java added or deleted
# 7ca9e6987d360e5475182d667606f4174416607d
# 0eb0b01cbf919cda6a56cc82eba063d034cbcd3e
# f344a4aed28dda85af039703f611c34e10bc14a9
# File common/buildcraft/core/gui/slots/SlotArchitect.java added or deleted
# 53c84a0ba349783443efb1487c2b6efd70672cb9
# f91b9033fa281f7eb39a0572635e056a4acca5b0
# c990c27ad2f43a7147389d098e9c68f047d86a56
# 6ffd45f3d7a657261a0c6026947bed277223c32d
# bed9b59b0e893ad78ddc0609df9d06d7d1cfbb93
# File api/buildcraft/api/mj/IBatteryObject.java added or deleted
# File api/buildcraft/api/mj/IBatteryProvider.java added or deleted
# 5c8bd331d3e371d31cb2aa49ab28e1141d6e7196
# File api/buildcraft/api/mj/BatteryObject.java added or deleted
# File api/buildcraft/api/mj/IBatteryObject.java added or deleted
# File api/buildcraft/api/mj/IBatteryProvider.java added or deleted
# 8f75c806184f737a1c4bdbfe222e6ef5712ffe89
# 9ad662a6fa5cfbd6d6db57f0b4eefcc1eea3fb6e
# 515060fff35cecc5a423d3ae423a096cc9616df4
# File api/buildcraft/api/mj/BatteryObject.java added or deleted
# File api/buildcraft/api/mj/IBatteryObject.java added or deleted
# File api/buildcraft/api/mj/IBatteryProvider.java added or deleted
# File common/buildcraft/core/gui/slots/SlotArchitect.java added or deleted
# File common/buildcraft/core/gui/slots/SlotBlueprintLibrary.java added or deleted
# 25a99b260883a27343e105f29f75787ab4226e66
# 4a0df699510a68f9193ec719f945e256846e1d59
# 25a99b260883a27343e105f29f75787ab4226e66
# 7c6c9f67f317607be910022c4022bb2bfb36487b
# File common/buildcraft/builders/schematics/SchematicRedstoneLamp.java added or deleted
# 4a0df699510a68f9193ec719f945e256846e1d59
# b2f8cf102dddd437b6fbf2a750dc175394a2bdaf
# 178d82ef9f9cca312153b472d56fc43056dfdaaf
# 684c6953421f6d20f56227b028c44bdf49c66139
# e18f01c784f140dd53f7ce694edd7d310a4a83f0
# 2738fbaef0b8b4cd9fe16d8eba185e6519869ad6
# File api/buildcraft/api/mj/ISidedBatteryProvider.java added or deleted
# 98d2e2e2e6ff5137b5cb13a659d4327e258e18ab
# File common/buildcraft/silicon/schematics/SchematicLaserTableBase.java added or deleted
# File common/buildcraft/transport/blueprints/BptItemPipeFilters.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeExtension.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeIron.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeWooden.java added or deleted
# File common/buildcraft/transport/blueprints/SchematicPipe.java added or deleted
# File common/buildcraft/transport/schematics/BptItemPipeEmerald.java added or deleted
# File common/buildcraft/transport/schematics/BptItemPipeFilters.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeExtension.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeIron.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeWooden.java added or deleted
# File common/buildcraft/transport/schematics/SchematicFilteredBuffer.java added or deleted
# File common/buildcraft/transport/schematics/SchematicPipe.java added or deleted
# a29c0a11408134a348dea25a7621e705a70562aa
# File common/buildcraft/transport/schematics/BptItemPipeEmerald.java added or deleted
# 577cf1125750aac6d2640b5ace9fd05f46aba6d5
# c0e07d7c0c47f13da4fee69bdab0749f03cbf0cf
# 30e4d493b3ea6e551d60e18d5e66a7393cff20c4
# 44e3aaa1c53806169cc59e528fa90aed3d0551b2
# 44e3aaa1c53806169cc59e528fa90aed3d0551b2
# 262f2dc22a4af9c166ada3a0f23c355a28f12137
# 49747b054ea02ac3386bbb603702006b157fe4ce
# 29d308f4f93d5bd966fe2071630d7def55890659
# 492b2805bf32ba7720cc41032ec7d31182404d32
# 4dcb9af87184f2f90ceece0f504abed1f039b092
# 1fc3890b96eb56936f1460aaeb77ad8065cf7248
# 9b02f71b549f5aaeb0f80551ac11330341fa8485
# 9b02f71b549f5aaeb0f80551ac11330341fa8485
# 9b02f71b549f5aaeb0f80551ac11330341fa8485
# bc1a7486cd465f5d7a701dff7c7f3a7b717b888e
# File common/buildcraft/transport/schematics/SchematicFilteredBuffer.java added or deleted
# a7fe30f38af9b673d8071c8e68055ccf8b148d9f
# f1d9aee0b8e1c052fff5b14e464e88ec33d15e17
# File api/buildcraft/api/blueprints/MappingNotFoundException.java added or deleted
# 1c90496cde15fa0d85c9db6fed3aa19ca710d68e
# c0412cc8311018688570e17c0010ceebd7e1ac56
# 986390babc7a014160ea228ebe0ee9371ee8d021
# 159eba4619453810f200caa93140f1bd717c43ce
# d584a18c44613a7cf8bf5cf559a88201583f5f1e
# c17041ac17af2edb7dd44bb4ed69ef95eab2213b
# File api/buildcraft/api/blueprints/MappingNotFoundException.java added or deleted
# File api/buildcraft/api/mj/ISidedBatteryProvider.java added or deleted
# File common/buildcraft/builders/schematics/SchematicRedstoneLamp.java added or deleted
# File common/buildcraft/silicon/schematics/SchematicLaserTableBase.java added or deleted
# File common/buildcraft/transport/blueprints/BptItemPipeFilters.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeExtension.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeIron.java added or deleted
# File common/buildcraft/transport/blueprints/BptPipeWooden.java added or deleted
# File common/buildcraft/transport/blueprints/SchematicPipe.java added or deleted
# File common/buildcraft/transport/schematics/BptItemPipeFilters.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeExtension.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeIron.java added or deleted
# File common/buildcraft/transport/schematics/BptPipeWooden.java added or deleted
# File common/buildcraft/transport/schematics/SchematicPipe.java added or deleted
# c96ff8666e17076ff7bce09f1fdb1219adce98d5
# 664ff00e7dc9ce2138c11afa6747ad4ade6054f7
# 030c8aa93dad296aa6e7746cd06ac4821f766c3e
# File api/buildcraft/api/mj/IBatteryIOObject.java added or deleted
# File api/buildcraft/api/mj/IOMode.java added or deleted
# 34e0bf9637fcc9298d5a2855c76b7fa493ab24f3
# af402df7f9e3691523209f7a193c8984c4048ee9
# 48fe5076a32130b356709c514724dd2ab78fe663
# 2eb8e868f2ba2ead73d8bd8ea938fb5dc810aa9c
# 527cc7d6d465149e78b65e47a0170359cd45b7fd
# 6c4dbb4297f03e2e7a8e3f54ccae5131f8bf03d6
# 6c4dbb4297f03e2e7a8e3f54ccae5131f8bf03d6
# 5be1d6031e73a5e189781466ed34c0b8555bc241
# 5be1d6031e73a5e189781466ed34c0b8555bc241
# 5be1d6031e73a5e189781466ed34c0b8555bc241
# 625b21719d786a7e1a5469a1acae5aadd9ef8b4b
# 5c4141970b47d04110e5f79fcf5b01f866556ccc
# aa24a99d956606b5efdb1da51548fd5d35f1e92f
# 82e804cd1338fb422a6cfc0b8e51f4f1d33a4971
# 9ec77056cc8a4dc633c57ce41ca84abe39d952c0
# 6f1294ab27b4a13ef2db7060959498f9c4200769
# 8f8529d4085936a66a9cbb20537e3d8f6cf4eec6
# ee1d7aeebce73d2bb073f01c6377d970d34ff067
# 6280266024b6d2213c245b1600bfbda915bbfd90
# e9b84c71217d3562b5de1bafd421fddbd72ddd80
# File tests/buildcraft/tests/ContainerTester.java added or deleted
# File tests/buildcraft/tests/GuiHandler.java added or deleted
# File tests/buildcraft/tests/GuiTestIds.java added or deleted
# File tests/buildcraft/tests/GuiTester.java added or deleted
# File tests/buildcraft/tests/testcase/BlockTestCase.java added or deleted
# File tests/buildcraft/tests/testcase/ContainerTestCase.java added or deleted
# File tests/buildcraft/tests/testcase/GuiTestCase.java added or deleted
# File tests/buildcraft/tests/testcase/Sequence.java added or deleted
# File tests/buildcraft/tests/testcase/SequenceAction.java added or deleted
# File tests/buildcraft/tests/testcase/SequenceActionUseItem.java added or deleted
# File tests/buildcraft/tests/testcase/TileTestCase.java added or deleted
# 3f460977727e48b6ec885c231cfd2071fc383c06
# f0af7f3b06618bc11b24bed9d57412eafcb20f49
# File tests/buildcraft/tests/testcase/SequenceActionCheckBlockMeta.java added or deleted
# 5a40c529cd215c94f0050bc21f0b99f622866f55
# 990c5bec91888f772bb8661297605b5f1c242644
# ce757bc37f0523953eacb83ad1081dc34ef91df5
# 58f342287a4999ac62f5a8d76d268e508b4fa485
# 45db58473e5b189083f91ea0d9a86275490130ea
# ae43e9cdb9b6208411ddc0a4604e78f616a9327e
# 79ddf231925d5d96308595772d4d47e3d4d403bd
# File common/buildcraft/core/robots/RobotAIMoveTo.java added or deleted
# 5060da651f3de4044f254458a4205fbd451f98b9
# File common/buildcraft/core/robots/RobotAIComposite.java added or deleted
# 0a4c84f55815da19d32b7b7a634377c46cf87fe3
# File api/buildcraft/api/mj/MjReconfigurator.java added or deleted
# File common/buildcraft/energy/TileEngineLegacy.java added or deleted
# 972d39f678053d20c8f7493d76ce9794820dafd1
# File common/buildcraft/core/robots/RobotAIDirectMoveTo.java added or deleted
# e8c1da1b755ecb9589247b45bfe6a31216ddc237
# File api/buildcraft/api/mj/MjReconfigurator.java added or deleted
# File common/buildcraft/energy/TileEngineLegacy.java added or deleted
# e5e8e4da4b057d4977c16fa3a48abad795bd1072
# 34d285a4484690d92fa785fb15da62d77a33d6db
# File common/buildcraft/silicon/ItemRedstoneBoard.java added or deleted
# File common/buildcraft/transport/pipes/PipePowerHeat.java added or deleted
# 5046cc445b7b29c8fee01875f2444e994c3b4c0a
# 379ea6e278f74633ae323493ec1c95f5cb4b34de
# 7acb8b45925613a1c5040c76ebf316bf9ed18782
# File api/buildcraft/api/boards/IRedstoneBoard.java added or deleted
# File api/buildcraft/api/boards/RedstoneBoardRegistry.java added or deleted
# File api/buildcraft/api/recipes/IAssemblyRecipe.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotPicker.java added or deleted
# File common/buildcraft/silicon/boards/BoardRecipe.java added or deleted
# File common/buildcraft/silicon/boards/ImplRedstoneBoardRegistry.java added or deleted
# e6ff3d7825f59d6c5b26c9159c47be1169703a0a
# f9748a5bfccd1a3160af10482e896b9e02e8a05e
# 9640255442a748061d5419fc072200e65717c974
# File api/buildcraft/api/mj/package-info.java added or deleted
# 173db45f4b7c910989d0970a739a8df77905bd77
# d3e3f8bf21a051100a934a92129ceb5524037135
# File common/buildcraft/core/network/INBTSerializable.java added or deleted
# File common/buildcraft/core/network/serializers/SerializerINBTSerializable.java added or deleted
# a3c2854791b0392177f38d765d0d5ec0b33ef57b
# a106b17da6281a8640ae579081173f19efc83ec6
# File api/buildcraft/api/mj/package-info.java added or deleted
# e204fa275d4959621d48a1edc0d2bc10c584206d
# File api/buildcraft/api/mj/package-info.java added or deleted
# 10e7429847956f2aa9f3e462ba5c217ed59eacbe
# b7a89c6cc87d4fbf6830bdc9a7ba9da8d1cacc9a
# File common/buildcraft/core/network/INBTSerializable.java added or deleted
# File common/buildcraft/core/network/serializers/SerializerINBTSerializable.java added or deleted
# d8d57e822f9bfb77960855fa24d144be90762b56
# ce55fe5eb1ab45012a229d9569ac287c30bd0ea4
# 3f925ae0e940417f4662d2becd504401e577dd66
# File api/buildcraft/api/boards/IRedstoneBoardRobot.java added or deleted
# File api/buildcraft/api/boards/IRedstoneBoardRobotNBT.java added or deleted
# File common/buildcraft/core/robots/EntityRobotBuilder.java added or deleted
# File common/buildcraft/core/robots/EntityRobotPicker.java added or deleted
# File common/buildcraft/core/robots/RobotIntegrationRecipe.java added or deleted
# 7b20cab4bef8e852018c3013661ffcc19f9265d6
# e99f0a3c4bace80a5454db2da45012cf7ac89933
# File api/buildcraft/api/boards/BoardParameter.java added or deleted
# d946f8d93639313fc6f2caae67816c74622d54fd
# 8bff3723601fff60826097ad66be4d39864fa01d
# 6150c5b09e0696cee055c726f13b556e12233811
# d946f8d93639313fc6f2caae67816c74622d54fd
# 8bff3723601fff60826097ad66be4d39864fa01d
# 917feacad8cde7f2e2f6230ba1e2b7be6036bbfc
# 7898637b331ccdcd17f13740d5ba55106f5021ad
# 917feacad8cde7f2e2f6230ba1e2b7be6036bbfc
# 7898637b331ccdcd17f13740d5ba55106f5021ad
# 7898637b331ccdcd17f13740d5ba55106f5021ad
# 742391e50476ca0dd358338a0f9837e207589a6a
# 1c49dddf356f1baced3a7972b41fa2e42ac9fa3f
# File api/buildcraft/api/recipes/IIntegrationRecipe.java added or deleted
# f005f28bb611ad1e90a4af001f35a5b9565c40c3
# 5a2100804b575d76ddd9aefa18a57c9da9f0ecff
# 02e8ef057e7656e86cd35da1d5187905d20ea99f
# File api/buildcraft/api/boards/BoardParameter.java added or deleted
# File api/buildcraft/api/boards/IRedstoneBoardNBT.java added or deleted
# File api/buildcraft/api/boards/IRedstoneBoardRobotNBT.java added or deleted
# a5b9a8870ed7d9d6a2e4f8155f7aacc08487fc0a
# ed1675ada52891ac5eb0a3f8d1c65f294a8af50b
# fd926ff0e0806446bc4554638ef3c049b4472316
# File api/buildcraft/api/blueprints/SchematicFluid.java added or deleted
# File common/buildcraft/builders/schematics/SchematicFluid.java added or deleted
# 6eec57c35f419782d32e0ccb2c91fe1d67c54de6
# 27754198ac69c978557a42ba7f8038d10beefd64
# eda4d58c9eeacfb83e0e395702fccba8ef8aff45
# 55bc2ef39a8f92497d17f4766d74df5081bc6460
# 05cf55b2241bc83c886c952a5883d76d4882df96
# da32818badd00d2f4a50005a207efa71bec3c634
# 1a74389a5caeb58cddbfae680b27a9ad4b7f5794
# 1518ccdcf6db7c61ca4feb7f644fbcac87315a0f
# File common/buildcraft/core/gui/FluidSlot.java added or deleted
# File common/buildcraft/core/gui/IInventorySlot.java added or deleted
# File common/buildcraft/core/gui/ItemSlot.java added or deleted
# File common/buildcraft/core/network/PacketRPCGui.java added or deleted
# 926764b0b5080b9415514b9ec345056453cdc7af
# 41479f2021bdd88cd4b3e604fdf6eca32d24ad87
# 87c18afb76a3c11d17a9356c32b00eb84017a75e
# 576be235f77de07abacb0238f6e5ebcdd90b30fa
# daae576b87e77957915bc77a01e14fe796f3ae68
# 9e58783addead22e96e2b1593ce21b9950f66b67
# File common/buildcraft/core/robots/boards/BoardRobotLumberjack.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotLumberjackNBT.java added or deleted
# 92bfbe4e273c6f527a4935d69300ac9669a96320
# 00521143b6434fbd147ab96c619705a84c6321c9
# 82b34ac62f7c64bf118fee25403e68182d223883
# File common/buildcraft/core/utils/IPathFound.java added or deleted
# 10fd47b0b99cdb8f5d7e3afc8e0c65a129bb8e5e
# b80c95ea03cd8506c0998372abf8e2513faa5452
# efcabd31a1a3fe453b45bbe3481f562fe4cf1ad2
# File common/buildcraft/core/network/PacketRPCEntity.java added or deleted
# cf393474ef55f8a543a834db4c548ce6168d34b9
# 7f5a993a07f95f1a41ed3f0e99a6a9219e266fa7
# 73bb09ca93a46d73fedbe44395487daebdc47f9e
# b8aeb05dd0ba534c159dc3e775d1740197c535bb
# 253c398f12f766d9e476cb49788b364b9ab004f8
# 0d978677de34de97a11ce84fc943d3f50882620a
# 1605a36c0341c1a5eadb61122196026c933559d3
# File api/buildcraft/robots/DockingStation.java added or deleted
# File api/buildcraft/robots/DockingStationRegistry.java added or deleted
# File common/buildcraft/core/robots/RobotAIGoToDock.java added or deleted
# b83f2ae6dcb5a8086f76b17b846d5d1caf6c27cf
# bdda0fb4762bab0ce04ddfd3e77fd821b6a3d4f0
# File api/buildcraft/api/boards/IRedstoneBoardRobot.java added or deleted
# File api/buildcraft/api/boards/RedstoneBoardRobot.java added or deleted
# File api/buildcraft/robots/AIRobot.java added or deleted
# File api/buildcraft/robots/EntityRobotBase.java added or deleted
# File common/buildcraft/core/robots/AIRobotGoToDock.java added or deleted
# File common/buildcraft/core/robots/AIRobotMain.java added or deleted
# File common/buildcraft/core/robots/AIRobotMove.java added or deleted
# File common/buildcraft/core/robots/AIRobotMoveToBlock.java added or deleted
# File common/buildcraft/core/robots/AIRobotStraightMoveTo.java added or deleted
# File common/buildcraft/core/robots/RobotAIBase.java added or deleted
# File common/buildcraft/core/robots/RobotAIComposite.java added or deleted
# File common/buildcraft/core/robots/RobotAIDirectMoveTo.java added or deleted
# File common/buildcraft/core/robots/RobotAIDocked.java added or deleted
# File common/buildcraft/core/robots/RobotAIGoToDock.java added or deleted
# File common/buildcraft/core/robots/RobotAIMoveAround.java added or deleted
# File common/buildcraft/core/robots/RobotAIMoveTo.java added or deleted
# File common/buildcraft/core/robots/RobotAIReturnToDock.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotCutWood.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotFetchAxe.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotFetchItem.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotGoToWood.java added or deleted
# d99505c7132d97899798139a38763fe1deaa738b
# 0ad90d29ce53231fbd300b64970ca16cd55d94b7
# 83e84f2687c92c06fa59cc96bac3705d84f08ce4
# aef8260877f31fbb50b359c3a8e3167689d8e494
# 53b517629734f00570d92deb811ed9f9ce80c573
# 878d5266bc2cd5fd7136095b8db1d97f4a831163
# 4931bc2954d64974b45ffd022e006d741b391597
# 27f9e0551278d9665f1314173791a0403b014943
# aeef94a888a24e8db7fc1478c4b852a5ade52e5d
# 6c52e912c75f9d6a98a73d8cb77658b86a36f23e
# File common/buildcraft/core/robots/AIRobotGoToWood.java added or deleted
# File common/buildcraft/core/utils/ChunkProperty.java added or deleted
# File common/buildcraft/core/utils/DimensionProperty.java added or deleted
# File common/buildcraft/core/utils/WorldProperty.java added or deleted
# File common/buildcraft/core/utils/WorldPropertyIsSoft.java added or deleted
# File common/buildcraft/core/utils/WorldPropertyIsWood.java added or deleted
# ce0c26f31d95804c201848ad15dc19b07b78bc08
# File common/buildcraft/core/utils/PathFindingJob.java added or deleted
# 1d642f052c7098f6c0cd141abd82506d241960a0
# defa5cab455f6df2650925dd3796c4bda22b7a7b
# 6389baa9cbc36889da93dd94b1e5c732e46b43a5
# File common/buildcraft/core/inventory/filters/OreStackFilter.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotFetchAxe.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotFetchItemStack.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotGoToRandomDirt.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotPlantSaple.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotPlanter.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotPlanterNBT.java added or deleted
# e60950db9b89ae28c0cc8dc4d9d8fd63780d61db
# 101f591f8f00df282063901fc30b1671dd9f2750
# File common/buildcraft/core/robots/boards/AIRobotBreakWithTool.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotCutWood.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotGoToWood.java added or deleted
# File common/buildcraft/core/robots/boards/AIRobotSearchBlock.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotGenericBreakBlock.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotLeaveCutter.java added or deleted
# File common/buildcraft/core/robots/boards/BoardRobotLeaveCutterNBT.java added or deleted
# File common/buildcraft/core/utils/WorldPropertyIsLeave.java added or deleted
# 66bfac926bd730e2163a058f9d140d285ae15dd2
# 5e6bc27144d03ae37e07e26e17c2d6a3be3bef84
# 98f7196d0f07e059bd03786a1cfc32cf2d7aa055
# b1076d85566d660a48fc2cf29f73812d3577ca49
# File api/buildcraft/api/core/BlockIndex.java added or deleted
# File api/buildcraft/api/core/IWorldProperty.java added or deleted
# File api/buildcraft/api/robots/AIRobot.java added or deleted
# File api/buildcraft/api/robots/DockingStationRegistry.java added or deleted
# File api/buildcraft/api/robots/EntityRobotBase.java added or deleted
# File api/buildcraft/api/robots/IDockingStation.java added or deleted
# File api/buildcraft/robots/AIRobot.java added or deleted
# File api/buildcraft/robots/DockingStation.java added or deleted
# File api/buildcraft/robots/DockingStationRegistry.java added or deleted
# File api/buildcraft/robots/EntityRobotBase.java added or deleted
# File common/buildcraft/core/BlockIndex.java added or deleted
# File common/buildcraft/core/robots/DockingStation.java added or deleted
# 1dcabf262b41d0919ef2f473eb677b167889f35f
# d8d42a3d1715140f598785c3bcdd379c0c3ba0f8
# 71687ec20c79ea9529514fd55478c07c10d40591
# 50ce9c48561a81b1d213ca96f3bc1765e62c7a34
# 50ce9c48561a81b1d213ca96f3bc1765e62c7a34
# eac76e9c774119ecb7ea75e1170281574a7580db
# 0ca64b0798eecc80aa139b018883a50eb6fb3681
# File common/buildcraft/core/ItemLocation.java added or deleted
# File common/buildcraft/core/ItemMapSpot.java added or deleted
# e308a0a3e223af2477d06e9b3b78d4745571b346
# 149e65d2c1bce157e7a32c254b0416512cd9ed41
# 7a71e6386171270603f69db8c9b497fdc3db970a
# 2aa15304448fad2957ae11548cbcf1855b05a5a1
# 31cc8b64385bb29c8a92477ef638237e60ddb7b6
# 40268062db5dc4f6672e6a0f0095236d8a16b072
# 0a9ffaf59f2718161f2c7a0ce4d36c6b0498b1f1
# 44d4e4e3b9b5e082a9818b33fcaefa82d01c227e
# File common/buildcraft/silicon/statements/ActionRobotGoToStation.java added or deleted
# File common/buildcraft/silicon/statements/RobotsActionProvider.java added or deleted
# File common/buildcraft/transport/utils/RobotStationMatrix.java added or deleted
# 254a533060f8ee026d0d602c42d80f8e2579ba8f
# File common/buildcraft/core/ItemLocation.java added or deleted
# File common/buildcraft/core/ItemMapLocation.java added or deleted
# File common/buildcraft/core/ItemMapSpot.java added or deleted
# c01bfe8783796995e309593d6c83639c0161954b
# File api/buildcraft/api/gates/IGate.java added or deleted
# File api/buildcraft/api/transport/IPipePluggable.java added or deleted
# File common/buildcraft/transport/utils/GateMatrix.java added or deleted
# bc51e2974679bf690e7c78a73bb48ce09e46f3fb
# File api/buildcraft/api/gates/IGate.java added or deleted
# File api/buildcraft/api/transport/IPipePluggable.java added or deleted
