# %%
import pandas as pd
import requests
import json
import time
from git import Repo
import re
from pathlib import Path
import git
from projects import project_list

# %%
fe = open('file_extensions.json', 'r')
file_extensions = json.load(fe)
types = list(file_extensions.keys())

# %%
def ignoreTheFormate(string_code):
    int1 = re.sub('/\/\/(.*)|\/\*(\*(?!\/)|[^*])*\*\//g', '', string_code) #removing single and multiline java comments
    int2 = re.sub('/([\\\]+<>=*(){}[,;-])/g', "\n$1\n", int1) 
    int3 = re.sub('/\s(\s*)/g', "\n", int2) #removing white spaces
    return int3.strip()

# %%
def getType(extension):
    
    for i in range(len(types)):
        if extension in file_extensions[types[i]]:
            return types[i]

    if (extension == ''):
        file_name = path.basename(file)
        if (file_name.indexOf('.git') == 0 |
            file_name.indexOf('.bzr') == 0 |
            file_name.indexOf('.svn') == 0 |
            file_name.indexOf('.cvs') == 0):
            return 'meta'
    
    return "unknown"

# %%
discard_list = []
for p in project_list[48:]:
    tr_data = pd.read_csv('data/25_1_travis_data/' + p)
    
    branch_type = tr_data['git_branch'].tolist()
    if 'master' in branch_type:
        data = tr_data[ tr_data['git_branch'] == 'master']
    else:
        data = tr_data[ tr_data['git_branch'] == 'trunk']
        
    if len(data) == 0:
        print('Could not continue for {}'.format(p))
        discard_list.append(p)
        continue
    
    repo_name = p.split('/')[0]
    clone_dir = 'project_clones/' + repo_name
    
    repo = Repo(clone_dir)
    verdict_list = [] #final decision

    for x in range(len(tr_data)):
        row = tr_data.iloc[x]
        commit_id = row['git_trigger_commit']
        print(commit_id)
        
        try:
            commit = repo.commit(commit_id)
        except:
            print('omitting {}'.format(commit_id))
            verdict_list.append(0)
            continue

        file_flag_list = []
        code_flag_list = []
        format_flag_list = []

        verdict = 1
    
        for file_name in commit.stats.files:

            extension = '.' + file_name.split('.')[-1]
            t = getType(extension)

            if (t == 'meta') | (t == 'media') | (t == 'doc'):
                file_flag_list.append(1)
                verdict = verdict & 1
                #we have found non-source code changes
                #we have found meta file changes

                #we have found that this file can be skipped 

            elif extension == '.java':
                try:
                    new_version = ignoreTheFormate(repo.git.show('{}:{}'.format(commit_id, file_name)))
                    old_version = ignoreTheFormate(repo.git.show('{}:{}'.format(commit_id + '~', file_name)))

                    if old_version != new_version:
                        #we have found code changes
                        #we have found that this file cannot be skipped
                        code_flag_list.append(0)
                        verdict = verdict & 0
                    else:
                        #we have found file formatting or comment changes
                        #we have found that this file can be skipped 
                        format_flag_list.append(1)
                        verdict = verdict & 1
                except:
                    #file added or deleted
                    print('File {} added or deleted'.format(file_name))
                    verdict = verdict & 0

            else:
                #out of skip rules scope
                verdict = verdict & 0
                continue

        verdict_list.append(verdict)
    
    tr_data['verdict'] = verdict_list
    p_name = p.split('/')[1]
    tr_data.to_csv( 'ci_skip_data/extracted_project_travis/'+ p_name )
    
    print(verdict_list.count(1), len(verdict_list), 100*verdict_list.count(1)/len(verdict_list))
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4,7,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 976fe1465d493a6278b221515c227e18c2348bd1
# 976fe1465d493a6278b221515c227e18c2348bd1
# 976fe1465d493a6278b221515c227e18c2348bd1
# 896aef210c874478fb7d788f372b8354b5b42c86
# 896aef210c874478fb7d788f372b8354b5b42c86
# 896aef210c874478fb7d788f372b8354b5b42c86
# 2b9aba0a763c5a34856971afb9ab1ec13b54a4e1
# File api/src/main/java/com/ning/billing/account/api/AccountChangeEvent.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/AccountCreationEvent.java added or deleted
# File api/src/main/java/com/ning/billing/entitlement/api/user/EffectiveSubscriptionEvent.java added or deleted
# File api/src/main/java/com/ning/billing/payment/api/PaymentEvent.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/DefaultBusInternalEvent.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# 2b9aba0a763c5a34856971afb9ab1ec13b54a4e1
# File api/src/main/java/com/ning/billing/account/api/AccountChangeEvent.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/AccountCreationEvent.java added or deleted
# File api/src/main/java/com/ning/billing/entitlement/api/user/EffectiveSubscriptionEvent.java added or deleted
# File api/src/main/java/com/ning/billing/payment/api/PaymentEvent.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/DefaultBusInternalEvent.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# 2b9aba0a763c5a34856971afb9ab1ec13b54a4e1
# File api/src/main/java/com/ning/billing/account/api/AccountChangeEvent.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/AccountCreationEvent.java added or deleted
# File api/src/main/java/com/ning/billing/entitlement/api/user/EffectiveSubscriptionEvent.java added or deleted
# File api/src/main/java/com/ning/billing/payment/api/PaymentEvent.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File api/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/DefaultBusInternalEvent.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequest.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestNotifier.java added or deleted
# File util/src/main/java/com/ning/billing/util/userrequest/CompletionUserRequestWaiter.java added or deleted
# b35d95b8d50d34fcf58394294ae1e871291f5844
# b35d95b8d50d34fcf58394294ae1e871291f5844
# b35d95b8d50d34fcf58394294ae1e871291f5844
# 752be1d398ebcf42223692ebd0561642e2955289
# 752be1d398ebcf42223692ebd0561642e2955289
# 752be1d398ebcf42223692ebd0561642e2955289
# 4dced98882c1c1cc6798ec0a840cde6272dcdca7
# 4dced98882c1c1cc6798ec0a840cde6272dcdca7
# 4dced98882c1c1cc6798ec0a840cde6272dcdca7
# 42f551eb4116038f27bb49a651c294a93d75fb57
# 42f551eb4116038f27bb49a651c294a93d75fb57
# 42f551eb4116038f27bb49a651c294a93d75fb57
# 4fee752ae48cbec502ec47357f2215f4fdd2bcd8
# 4fee752ae48cbec502ec47357f2215f4fdd2bcd8
# 4fee752ae48cbec502ec47357f2215f4fdd2bcd8
# 68591fac2addecefb01b41cd2afc7fd917c2cbe2
# 68591fac2addecefb01b41cd2afc7fd917c2cbe2
# 68591fac2addecefb01b41cd2afc7fd917c2cbe2
# 6087482596fa4f04ea3724b6214779491a1b90aa
# 6087482596fa4f04ea3724b6214779491a1b90aa
# 6087482596fa4f04ea3724b6214779491a1b90aa
# 0c366a471b38e60a0dcfc3d0a51148556324bf55
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File api/src/main/java/com/ning/billing/util/bus/BusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/DefaultBeatrixService.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/BeatrixListener.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/DefaultBusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/PersistentExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusEventEntry.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusSqlDao.java added or deleted
# File beatrix/src/test/java/com/ning/billing/beatrix/integration/TestPublicBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/Bus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/InternalBus.java added or deleted
# 0c366a471b38e60a0dcfc3d0a51148556324bf55
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File api/src/main/java/com/ning/billing/util/bus/BusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/DefaultBeatrixService.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/BeatrixListener.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/DefaultBusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/PersistentExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusEventEntry.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusSqlDao.java added or deleted
# File beatrix/src/test/java/com/ning/billing/beatrix/integration/TestPublicBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/Bus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/InternalBus.java added or deleted
# 0c366a471b38e60a0dcfc3d0a51148556324bf55
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File api/src/main/java/com/ning/billing/util/bus/BusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/DefaultBeatrixService.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/BeatrixListener.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/DefaultBusEvent.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/PersistentExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusEventEntry.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/extbus/dao/ExtBusSqlDao.java added or deleted
# File beatrix/src/test/java/com/ning/billing/beatrix/integration/TestPublicBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/InMemoryInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/bus/PersistentInternalBus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/Bus.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcsapi/bus/InternalBus.java added or deleted
# e27446fddd91ef65c9cf5f38a7e2a97d3f5737e3
# File api/src/main/java/com/ning/billing/entitlement/api/user/SubscriptionTransition.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# e27446fddd91ef65c9cf5f38a7e2a97d3f5737e3
# File api/src/main/java/com/ning/billing/entitlement/api/user/SubscriptionTransition.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# e27446fddd91ef65c9cf5f38a7e2a97d3f5737e3
# File api/src/main/java/com/ning/billing/entitlement/api/user/SubscriptionTransition.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# fd27341af3bf971cd51918845bddba020d17ef4d
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# fd27341af3bf971cd51918845bddba020d17ef4d
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# fd27341af3bf971cd51918845bddba020d17ef4d
# File api/src/main/java/com/ning/billing/beatrix/bus/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/ExternalBus.java added or deleted
# File beatrix/src/main/java/com/ning/billing/beatrix/BeatrixService.java added or deleted
# 204934573614817ab3fdf69f71e59018aca582e9
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BeatrixService.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExternalBus.java added or deleted
# 204934573614817ab3fdf69f71e59018aca582e9
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BeatrixService.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExternalBus.java added or deleted
# 204934573614817ab3fdf69f71e59018aca582e9
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BeatrixService.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEventType.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExternalBus.java added or deleted
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# 2a65b82d6cbdd8b97c63292213f0f7cdc182416f
# db05c85a1224268249e9bd28a084e6a6258857b8
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEvent.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/NotificationJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/TenantKeyJson.java added or deleted
# File overdue/src/main/java/com/ning/billing/overdue/service/ExtendedOverdueService.java added or deleted
# File server/src/main/java/com/ning/billing/server/DefaultServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/ServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/notifications/PushNotificationListener.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestJetty.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# db05c85a1224268249e9bd28a084e6a6258857b8
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEvent.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/NotificationJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/TenantKeyJson.java added or deleted
# File overdue/src/main/java/com/ning/billing/overdue/service/ExtendedOverdueService.java added or deleted
# File server/src/main/java/com/ning/billing/server/DefaultServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/ServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/notifications/PushNotificationListener.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestJetty.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# db05c85a1224268249e9bd28a084e6a6258857b8
# File api/src/main/java/com/ning/billing/beatrix/bus/api/BusEvent.java added or deleted
# File api/src/main/java/com/ning/billing/beatrix/bus/api/ExtBusEvent.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/NotificationJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/TenantKeyJson.java added or deleted
# File overdue/src/main/java/com/ning/billing/overdue/service/ExtendedOverdueService.java added or deleted
# File server/src/main/java/com/ning/billing/server/DefaultServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/ServerService.java added or deleted
# File server/src/main/java/com/ning/billing/server/notifications/PushNotificationListener.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestJetty.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 592c5291c55e09ae38b7054882470cf55784d4e6
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 592c5291c55e09ae38b7054882470cf55784d4e6
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 592c5291c55e09ae38b7054882470cf55784d4e6
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 756620ce9a303077c6a73a22ca9a5321a764b3e2
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 756620ce9a303077c6a73a22ca9a5321a764b3e2
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 756620ce9a303077c6a73a22ca9a5321a764b3e2
# File server/src/test/java/com/ning/billing/jaxrs/TestPushNotification.java added or deleted
# File server/src/test/java/com/ning/billing/jaxrs/TestTenant.java added or deleted
# 25e952084e61de645a1ff6b7f0d46d1c192662ed
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 25e952084e61de645a1ff6b7f0d46d1c192662ed
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 25e952084e61de645a1ff6b7f0d46d1c192662ed
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 8866f4283c392ee4a45bddd9a1d9d7217d2a565e
# 8866f4283c392ee4a45bddd9a1d9d7217d2a565e
# 8866f4283c392ee4a45bddd9a1d9d7217d2a565e
# d55dcfed543820b75b7308f2dfacb24cb8459efe
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# d55dcfed543820b75b7308f2dfacb24cb8459efe
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# d55dcfed543820b75b7308f2dfacb24cb8459efe
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 526f4f54d23df50ffa8d7ec23800e9794b61e470
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 526f4f54d23df50ffa8d7ec23800e9794b61e470
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# 526f4f54d23df50ffa8d7ec23800e9794b61e470
# File entitlement/src/test/java/com/ning/billing/entitlement/api/transfer/TestDefaultEntitlementTransferApi.java added or deleted
# e03cb29ba45c84baf6a64708151ba091b26711b3
# e03cb29ba45c84baf6a64708151ba091b26711b3
# e03cb29ba45c84baf6a64708151ba091b26711b3
# 4a7f6bf4681371479a20db7fb9b5ae54f1e3922e
# 4a7f6bf4681371479a20db7fb9b5ae54f1e3922e
# 4a7f6bf4681371479a20db7fb9b5ae54f1e3922e
# c81d5b2b937a9983d34a3407131e3fd615db2f9e
# c81d5b2b937a9983d34a3407131e3fd615db2f9e
# c81d5b2b937a9983d34a3407131e3fd615db2f9e
# c0fd0a6e4b97126cecdb6192b962940aaba3f1f2
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# c0fd0a6e4b97126cecdb6192b962940aaba3f1f2
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# c0fd0a6e4b97126cecdb6192b962940aaba3f1f2
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# aee5eae182ca641ad349e7e01344fa8aecad7dcc
# aee5eae182ca641ad349e7e01344fa8aecad7dcc
# aee5eae182ca641ad349e7e01344fa8aecad7dcc
# b3ce7ecf78b40add135c81916feee5cdc1c714eb
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessAccount.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoice.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoicePayment.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessOverdueStatus.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSnapshot.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSubscriptionTransition.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessTag.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessAccount.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessField.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoice.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoicePayment.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessOverdueStatus.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSnapshot.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSubscriptionTransition.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessTag.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessAccountJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessFieldJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoiceJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoicePaymentJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessOverdueStatusJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSnapshotJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSubscriptionTransitionJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessTagJson.java added or deleted
# b3ce7ecf78b40add135c81916feee5cdc1c714eb
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessAccount.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoice.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoicePayment.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessOverdueStatus.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSnapshot.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSubscriptionTransition.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessTag.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessAccount.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessField.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoice.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoicePayment.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessOverdueStatus.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSnapshot.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSubscriptionTransition.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessTag.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessAccountJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessFieldJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoiceJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoicePaymentJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessOverdueStatusJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSnapshotJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSubscriptionTransitionJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessTagJson.java added or deleted
# b3ce7ecf78b40add135c81916feee5cdc1c714eb
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessAccount.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoice.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoicePayment.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessOverdueStatus.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSnapshot.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSubscriptionTransition.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessTag.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessAccount.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessField.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoice.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoicePayment.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessOverdueStatus.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSnapshot.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSubscriptionTransition.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessTag.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessAccountJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessFieldJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoiceJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessInvoicePaymentJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessOverdueStatusJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSnapshotJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessSubscriptionTransitionJson.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/BusinessTagJson.java added or deleted
# 4af322619fec3725e490a147fef306cedbc4a780
# 4af322619fec3725e490a147fef306cedbc4a780
# 4af322619fec3725e490a147fef306cedbc4a780
# 91f443f6e182e752ac9360614b75db46c3458f37
# 91f443f6e182e752ac9360614b75db46c3458f37
# 91f443f6e182e752ac9360614b75db46c3458f37
# 74171668be2223a2f664abb1e0b08fabdb18742a
# 74171668be2223a2f664abb1e0b08fabdb18742a
# 74171668be2223a2f664abb1e0b08fabdb18742a
# 24637a6ca3f4811d66b31d8c529f3996f239cccc
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# 24637a6ca3f4811d66b31d8c529f3996f239cccc
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# 24637a6ca3f4811d66b31d8c529f3996f239cccc
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# 658d31f7024dacace69a3e0f486884e52b71a9f8
# 658d31f7024dacace69a3e0f486884e52b71a9f8
# 658d31f7024dacace69a3e0f486884e52b71a9f8
# 16dcde2512513a73325bd56dd75f28567fd93782
# File analytics/src/main/java/com/ning/billing/analytics/api/sanity/DefaultAnalyticsSanityApi.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanityDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanitySqlDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/DefaultAnalyticsSanityDao.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/sanity/AnalyticsSanityApi.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/AnalyticsSanityJson.java added or deleted
# 16dcde2512513a73325bd56dd75f28567fd93782
# File analytics/src/main/java/com/ning/billing/analytics/api/sanity/DefaultAnalyticsSanityApi.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanityDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanitySqlDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/DefaultAnalyticsSanityDao.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/sanity/AnalyticsSanityApi.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/AnalyticsSanityJson.java added or deleted
# 16dcde2512513a73325bd56dd75f28567fd93782
# File analytics/src/main/java/com/ning/billing/analytics/api/sanity/DefaultAnalyticsSanityApi.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanityDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanitySqlDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/DefaultAnalyticsSanityDao.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/sanity/AnalyticsSanityApi.java added or deleted
# File jaxrs/src/main/java/com/ning/billing/jaxrs/json/AnalyticsSanityJson.java added or deleted
# 68327504db67b61b180bb9ec3b21ca48f44b1b3e
# 68327504db67b61b180bb9ec3b21ca48f44b1b3e
# 68327504db67b61b180bb9ec3b21ca48f44b1b3e
# 0193f0105720c96e1b1ceedccc0858afd07abda4
# File api/src/main/java/com/ning/billing/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File api/src/main/java/com/ning/billing/config/CatalogConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/EntitlementConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/InvoiceConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/KillbillConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/NotificationConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PaymentConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PersistentQueueConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/UsageConfig.java added or deleted
# File api/src/main/java/com/ning/billing/util/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/audit/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/dao/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/CatalogConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/EntitlementConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/InvoiceConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/KillbillConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/NotificationConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PaymentConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PersistentQueueConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UsageConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# 0193f0105720c96e1b1ceedccc0858afd07abda4
# File api/src/main/java/com/ning/billing/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File api/src/main/java/com/ning/billing/config/CatalogConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/EntitlementConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/InvoiceConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/KillbillConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/NotificationConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PaymentConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PersistentQueueConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/UsageConfig.java added or deleted
# File api/src/main/java/com/ning/billing/util/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/audit/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/dao/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/CatalogConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/EntitlementConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/InvoiceConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/KillbillConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/NotificationConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PaymentConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PersistentQueueConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UsageConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# 0193f0105720c96e1b1ceedccc0858afd07abda4
# File api/src/main/java/com/ning/billing/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/account/api/ChangedField.java added or deleted
# File api/src/main/java/com/ning/billing/config/CatalogConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/EntitlementConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/InvoiceConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/KillbillConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/NotificationConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PaymentConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/PersistentQueueConfig.java added or deleted
# File api/src/main/java/com/ning/billing/config/UsageConfig.java added or deleted
# File api/src/main/java/com/ning/billing/util/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/audit/ChangeType.java added or deleted
# File api/src/main/java/com/ning/billing/util/dao/ObjectType.java added or deleted
# File api/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File payment/src/main/java/com/ning/billing/payment/api/svcs/DefaultPaymentInternalApi.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/CatalogConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/EntitlementConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/InvoiceConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/KillbillConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/NotificationConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PaymentConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/PersistentQueueConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/UsageConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/UriAccessor.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidatingConfig.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationError.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationErrors.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/ValidationException.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLLoader.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLSchemaGenerator.java added or deleted
# File util/src/main/java/com/ning/billing/util/config/catalog/XMLWriter.java added or deleted
# File util/src/main/java/com/ning/billing/util/events/ChangedField.java added or deleted
# File util/src/main/java/com/ning/billing/util/queue/QueueLifecycle.java added or deleted
# File util/src/main/java/com/ning/billing/util/svcapi/payment/PaymentInternalApi.java added or deleted
# 65421f0281855a1467e1293b23f2277682efa8a0
# 65421f0281855a1467e1293b23f2277682efa8a0
# 65421f0281855a1467e1293b23f2277682efa8a0
# 110f70ef86bccddaafd0217839cb820b043a2b65
# 110f70ef86bccddaafd0217839cb820b043a2b65
# 110f70ef86bccddaafd0217839cb820b043a2b65
# cb7d7f9d85e67f6d1a4a78ca6a4b543f747cd357
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessAccount.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoice.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessInvoicePayment.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessOverdueStatus.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSnapshot.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessSubscriptionTransition.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/DefaultBusinessTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/api/sanity/DefaultAnalyticsSanityApi.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanityDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/AnalyticsSanitySqlDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/dao/DefaultAnalyticsSanityDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccount.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccountField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccountFieldModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccountModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccountTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessAccountTagModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessFieldModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoice.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceFieldModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceItem.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceItemModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePayment.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePaymentField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePaymentFieldModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePaymentModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePaymentTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoicePaymentTagModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessInvoiceTagModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessOverdueStatus.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessOverdueStatusModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransition.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransitionField.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransitionFieldModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransitionModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransitionTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessSubscriptionTransitionTagModelDao.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessTag.java added or deleted
# File analytics/src/main/java/com/ning/billing/analytics/model/BusinessTagModelDao.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessAccount.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessField.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoice.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessInvoicePayment.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessOverdueStatus.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSnapshot.java added or deleted
# File api/src/main/java/com/ning/billing/analytics/api/BusinessSubscriptionTransition.java added or deleted
# ...
# File api/src/main/java/org/killbill/billing/events/EffectiveEntitlementInternalEvent.java added or deleted
# File api/src/main/java/org/killbill/billing/invoice/api/InvoiceMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApiException.java added or deleted
# File api/src/main/java/org/killbill/billing/util/AccountDateAndTimeZoneContext.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuite.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuiteNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/BeatrixIntegrationModuleNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/TestMigrationSubscriptions.java added or deleted
# File catalog/src/main/java/org/killbill/billing/catalog/CatalogDateHelper.java added or deleted
# File entitlement/src/main/java/org/killbill/billing/entitlement/api/DefaultEffectiveEntitlementEvent.java added or deleted
# File entitlement/src/test/java/org/killbill/billing/entitlement/api/TestRegessionSubscriptionApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/api/migration/DefaultInvoiceMigrationApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/model/MigrationInvoiceItem.java added or deleted
# File jaxrs/src/main/java/org/killbill/billing/jaxrs/mappers/IllegalStateExceptionMapper.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/jaxrs/TestUsage.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/server/log/TestServerModuleNoDB.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/MigrationPlanAligner.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/TimedMigration.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/AccountMigrationData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/DefaultSubscriptionBaseMigrationApi.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/BundleTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/SubscriptionTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateBilling.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateSubscription.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventReCreate.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/alignment/TestTimedMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/migration/TestMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/user/TestUserApiRecreate.java added or deleted
# File util/src/main/java/org/killbill/billing/util/account/AccountDateTimeUtils.java added or deleted
# File util/src/main/java/org/killbill/billing/util/glue/NoCachingInternalCallContextFactoryProvider.java added or deleted
# File util/src/main/java/org/killbill/billing/util/timezone/DefaultAccountDateAndTimeZoneContext.java added or deleted
# File util/src/test/java/org/killbill/billing/callcontext/MutableInternalCallContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/callcontext/TestTimeAwareContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/timezone/TestDateAndTimeZoneContext.java added or deleted
# 3ff7d232e3fbf4a9d9abd9d7d71df7a2740079f9
# File account/src/main/java/org/killbill/billing/account/api/svcs/DefaultImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/ImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/MigrationAccountData.java added or deleted
# File api/src/main/java/org/killbill/billing/callcontext/TimeAwareContext.java added or deleted
# File api/src/main/java/org/killbill/billing/events/EffectiveEntitlementInternalEvent.java added or deleted
# File api/src/main/java/org/killbill/billing/invoice/api/InvoiceMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApiException.java added or deleted
# File api/src/main/java/org/killbill/billing/util/AccountDateAndTimeZoneContext.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuite.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuiteNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/BeatrixIntegrationModuleNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/TestMigrationSubscriptions.java added or deleted
# File catalog/src/main/java/org/killbill/billing/catalog/CatalogDateHelper.java added or deleted
# File entitlement/src/main/java/org/killbill/billing/entitlement/api/DefaultEffectiveEntitlementEvent.java added or deleted
# File entitlement/src/test/java/org/killbill/billing/entitlement/api/TestRegessionSubscriptionApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/api/migration/DefaultInvoiceMigrationApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/model/MigrationInvoiceItem.java added or deleted
# File jaxrs/src/main/java/org/killbill/billing/jaxrs/mappers/IllegalStateExceptionMapper.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/jaxrs/TestUsage.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/server/log/TestServerModuleNoDB.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/MigrationPlanAligner.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/TimedMigration.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/AccountMigrationData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/DefaultSubscriptionBaseMigrationApi.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/BundleTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/SubscriptionTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateBilling.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateSubscription.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventReCreate.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/alignment/TestTimedMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/migration/TestMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/user/TestUserApiRecreate.java added or deleted
# File util/src/main/java/org/killbill/billing/util/account/AccountDateTimeUtils.java added or deleted
# File util/src/main/java/org/killbill/billing/util/glue/NoCachingInternalCallContextFactoryProvider.java added or deleted
# File util/src/main/java/org/killbill/billing/util/timezone/DefaultAccountDateAndTimeZoneContext.java added or deleted
# File util/src/test/java/org/killbill/billing/callcontext/MutableInternalCallContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/callcontext/TestTimeAwareContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/timezone/TestDateAndTimeZoneContext.java added or deleted
# 3ff7d232e3fbf4a9d9abd9d7d71df7a2740079f9
# File account/src/main/java/org/killbill/billing/account/api/svcs/DefaultImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/ImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/MigrationAccountData.java added or deleted
# File api/src/main/java/org/killbill/billing/callcontext/TimeAwareContext.java added or deleted
# File api/src/main/java/org/killbill/billing/events/EffectiveEntitlementInternalEvent.java added or deleted
# File api/src/main/java/org/killbill/billing/invoice/api/InvoiceMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApiException.java added or deleted
# File api/src/main/java/org/killbill/billing/util/AccountDateAndTimeZoneContext.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuite.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuiteNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/BeatrixIntegrationModuleNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/TestMigrationSubscriptions.java added or deleted
# File catalog/src/main/java/org/killbill/billing/catalog/CatalogDateHelper.java added or deleted
# File entitlement/src/main/java/org/killbill/billing/entitlement/api/DefaultEffectiveEntitlementEvent.java added or deleted
# File entitlement/src/test/java/org/killbill/billing/entitlement/api/TestRegessionSubscriptionApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/api/migration/DefaultInvoiceMigrationApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/model/MigrationInvoiceItem.java added or deleted
# File jaxrs/src/main/java/org/killbill/billing/jaxrs/mappers/IllegalStateExceptionMapper.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/jaxrs/TestUsage.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/server/log/TestServerModuleNoDB.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/MigrationPlanAligner.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/TimedMigration.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/AccountMigrationData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/DefaultSubscriptionBaseMigrationApi.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/BundleTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/SubscriptionTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateBilling.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventMigrateSubscription.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/events/user/ApiEventReCreate.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/alignment/TestTimedMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/migration/TestMigration.java added or deleted
# File subscription/src/test/java/org/killbill/billing/subscription/api/user/TestUserApiRecreate.java added or deleted
# File util/src/main/java/org/killbill/billing/util/account/AccountDateTimeUtils.java added or deleted
# File util/src/main/java/org/killbill/billing/util/glue/NoCachingInternalCallContextFactoryProvider.java added or deleted
# File util/src/main/java/org/killbill/billing/util/timezone/DefaultAccountDateAndTimeZoneContext.java added or deleted
# File util/src/test/java/org/killbill/billing/callcontext/MutableInternalCallContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/callcontext/TestTimeAwareContext.java added or deleted
# File util/src/test/java/org/killbill/billing/util/timezone/TestDateAndTimeZoneContext.java added or deleted
# 3ff7d232e3fbf4a9d9abd9d7d71df7a2740079f9
# File account/src/main/java/org/killbill/billing/account/api/svcs/DefaultImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/ImmutableAccountInternalApi.java added or deleted
# File api/src/main/java/org/killbill/billing/account/api/MigrationAccountData.java added or deleted
# File api/src/main/java/org/killbill/billing/callcontext/TimeAwareContext.java added or deleted
# File api/src/main/java/org/killbill/billing/events/EffectiveEntitlementInternalEvent.java added or deleted
# File api/src/main/java/org/killbill/billing/invoice/api/InvoiceMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApi.java added or deleted
# File api/src/main/java/org/killbill/billing/subscription/api/migration/SubscriptionBaseMigrationApiException.java added or deleted
# File api/src/main/java/org/killbill/billing/util/AccountDateAndTimeZoneContext.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuite.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/BeatrixTestSuiteNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/BeatrixIntegrationModuleNoDB.java added or deleted
# File beatrix/src/test/java/org/killbill/billing/beatrix/integration/TestMigrationSubscriptions.java added or deleted
# File catalog/src/main/java/org/killbill/billing/catalog/CatalogDateHelper.java added or deleted
# File entitlement/src/main/java/org/killbill/billing/entitlement/api/DefaultEffectiveEntitlementEvent.java added or deleted
# File entitlement/src/test/java/org/killbill/billing/entitlement/api/TestRegessionSubscriptionApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/api/migration/DefaultInvoiceMigrationApi.java added or deleted
# File invoice/src/main/java/org/killbill/billing/invoice/model/MigrationInvoiceItem.java added or deleted
# File jaxrs/src/main/java/org/killbill/billing/jaxrs/mappers/IllegalStateExceptionMapper.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/jaxrs/TestUsage.java added or deleted
# File profiles/killbill/src/test/java/org/killbill/billing/server/log/TestServerModuleNoDB.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/MigrationPlanAligner.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/alignment/TimedMigration.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/AccountMigrationData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/migration/DefaultSubscriptionBaseMigrationApi.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/BundleTransferData.java added or deleted
# File subscription/src/main/java/org/killbill/billing/subscription/api/transfer/SubscriptionTransferData.java added or deleted
