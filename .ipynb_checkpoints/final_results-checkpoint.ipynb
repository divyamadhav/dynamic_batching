# %%
import pandas as pd

# %%
baseline_dynamic = pd.read_csv('ci&baseline_dynamic_batching.csv')
our_dynamic = pd.read_csv('new_dynamic_batching.csv')
our_ci_dynamic = pd.read_csv('ci_skipped_dynamic_batching.csv')
baseline_static = pd.read_csv('static_baseline_batching.csv')
baseline_ci_static = pd.read_csv('ci_skipped_static_baseline_batching.csv')

# %%
our_dynamic['ci_skip'] = [0]*len(our_dynamic)
our_ci_dynamic['ci_skip'] = [0]*len(our_ci_dynamic)
baseline_static['ci_skip'] = [0]*len(baseline_static)
baseline_ci_static['ci_skip'] = [0]*len(baseline_ci_static)

# %%
final_results = pd.DataFrame()
final_results = final_results.append(baseline_dynamic)
final_results = final_results.append(our_dynamic)
final_results = final_results.append(our_ci_dynamic)
final_results = final_results.append(baseline_static)
final_results = final_results.append(baseline_ci_static)

# %%
final_results
# Out:
#                 project    algorithm  ci_skip  batch_size  builds_saved  \
# 0            okhttp.csv  BATCHBISECT        0          -1      6.729178
# 1            gradle.csv  BATCHBISECT        0          -1     44.492255
# 2          cloudify.csv  BATCHBISECT        0          -1     34.200079
# 3           android.csv  BATCHBISECT        0          -1     62.148338
# 4   graylog2-server.csv  BATCHBISECT        0          -1     60.049875
# ..                  ...          ...      ...         ...           ...
# 25         cloudify.csv  BATCHBISECT        0           4     26.065509
# 26         cloudify.csv  BATCHBISECT        0           8     25.335438
# 27         cloudify.csv  BATCHBISECT        0          16     22.711129
# 28         cloudify.csv   BATCHSTOP4        0           8     35.280189
# 29         cloudify.csv   BATCHSTOP4        0          16     32.655880
#
#     median_delay  testall_size
# 0           -1.0          1813
# 1           -1.0          3486
# 2           -1.0          5038
# 3           -1.0           782
# 4           -1.0          2005
# ..           ...           ...
# 25           1.5          5068
# 26           4.0          5068
# 27           8.0          5068
# 28           4.0          5068
# 29           8.0          5068
#
# [156 rows x 7 columns]

# %%
final_results.to_csv('ci_skip_final_results.csv')
