# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('replication/19314170/final-2017-01-25.csv')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,6,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
java = data[ data['gh_lang'] == 'java']

# %%
projects = set(java['gh_project_name'].tolist())

# %%
l = []

# %%
for p in projects:
    d = java[ java['gh_project_name'] == p]
    l.append(len(d))

# %%
l.sort()

# %%
l
# Out:
# [1,
#  2,
#  3,
#  4,
#  4,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  9,
#  10,
#  10,
#  12,
#  13,
#  14,
#  16,
#  17,
#  17,
#  17,
#  19,
#  22,
#  24,
#  26,
#  26,
#  29,
#  31,
#  32,
#  32,
#  33,
#  35,
#  47,
#  47,
#  56,
#  65,
#  66,
#  70,
#  71,
#  72,
#  73,
#  76,
#  78,
#  81,
#  84,
#  89,
#  92,
#  94,
#  104,
#  110,
#  114,
#  115,
#  118,
#  124,
#  126,
#  135,
#  138,
#  145,
#  147,
#  153,
#  156,
#  176,
#  179,
#  200,
#  203,
#  209,
#  229,
#  235,
#  235,
#  236,
#  242,
#  246,
#  247,
#  247,
#  255,
#  261,
#  296,
#  297,
#  301,
#  305,
#  308,
#  308,
#  315,
#  316,
#  317,
#  323,
#  327,
#  336,
#  340,
#  346,
#  352,
#  372,
#  386,
#  396,
#  396,
#  406,
#  408,
#  410,
#  410,
#  422,
#  428,
#  439,
#  452,
#  452,
#  457,
#  484,
#  488,
#  492,
#  494,
#  499,
#  521,
#  521,
#  535,
#  551,
#  565,
#  569,
#  586,
#  587,
#  593,
#  594,
#  598,
#  619,
#  657,
#  669,
#  673,
#  706,
#  723,
#  735,
#  735,
#  737,
#  744,
#  759,
#  762,
#  799,
#  800,
#  805,
#  846,
#  883,
#  895,
#  899,
#  908,
#  929,
#  932,
#  932,
#  940,
#  967,
#  1030,
#  1037,
#  1051,
#  1058,
#  1061,
#  1137,
#  1171,
#  1179,
#  1198,
#  1231,
#  1259,
#  1269,
#  1314,
#  1318,
#  1348,
#  1375,
#  1422,
#  1467,
#  1474,
#  1490,
#  1548,
#  1560,
#  1574,
#  1576,
#  1590,
#  1635,
#  1637,
#  1641,
#  1690,
#  1694,
#  1702,
#  1790,
#  1844,
#  1848,
#  1874,
#  1910,
#  1910,
#  1928,
#  1971,
#  1992,
#  2011,
#  2014,
#  2040,
#  2056,
#  2081,
#  2134,
#  2162,
#  2187,
#  2252,
#  2349,
#  2378,
#  2390,
#  2404,
#  2449,
#  2526,
#  2540,
#  2591,
#  2772,
#  2789,
#  2848,
#  2965,
#  3070,
#  3186,
#  3221,
#  3258,
#  3414,
#  3678,
#  3743,
#  3771,
#  3807,
#  3880,
#  3977,
#  4045,
#  4214,
#  4537,
#  4666,
#  4848,
#  5598,
#  5752,
#  5754,
#  6040,
#  6305,
#  6742,
#  6940,
#  7236,
#  8862,
#  8978,
#  9430,
#  10643,
#  15041,
#  16278,
#  18120,
#  46889]
